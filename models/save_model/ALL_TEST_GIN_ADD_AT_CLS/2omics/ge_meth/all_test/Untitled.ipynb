# %%
import pandas as pd

# %%
a = pd.read_csv("detail_result_test.csv")

# %%
a.sort_values(["x_1_ats"])
# Out:
#           Drug1      Drug2 Cell line  Cosmic sample Id    synergy  Tissue  \
# 6642    MK-2206  ERLOTINIB    NCIH23            905942  21.531915    lung
# 4721    MK-2206  ERLOTINIB  MDAMB436           1240172  17.514154  breast
# 6180    MK-2206  ERLOTINIB     HT144            907067  20.261331    skin
# 8488    MK-2206  ERLOTINIB  NCIH1650            687800  53.902587    lung
# 4271    MK-2206  ERLOTINIB      A375            906793   5.470406    skin
# ...         ...        ...       ...               ...        ...     ...
# 4720  ERLOTINIB    MK-2206  MDAMB436           1240172  17.514154  breast
# 4270  ERLOTINIB    MK-2206      A375            906793   5.470406    skin
# 8489  ERLOTINIB    MK-2206  NCIH1650            687800  53.902587    lung
# 1260  ERLOTINIB    MK-2206   SKMEL30            909726   9.958446    skin
# 6181  ERLOTINIB    MK-2206     HT144            907067  20.261331    skin
#
#       log_synergy    predict  abs_error   x_1_ats   x_2_ats
# ...
